# %%
## Utility to copy notebooks from one workspace to another, in an ad-hoc manner

# Imports
from firecloud import api as fapi
import json
import os
import pandas as pd
import csv
from io import StringIO
from google.cloud import storage
import re
import hashlib

# Functions
def get_notebooks_list(source_bucket, user_project, nbs_to_include=[], nbs_to_exclude=[]):
    
    # Collect list of objects/blobs from bucket 
    obj_list = []
    storage_client = storage.Client()
    storage_bucket = storage_client.bucket(source_bucket, user_project=user_project)
    objects = list(storage_client.list_blobs(storage_bucket, prefix = 'notebooks'))
    
    # Loop through list of objects and append names to final list
    for obj in objects:
        notebook_name = obj.name.split('/')[1]
        if len(nbs_to_include) > 0:
            for entry in nbs_to_include:
                if entry == notebook_name:
                    obj_list.append(notebook_name)
        else:
            obj_list.append(notebook_name)
        if len(nbs_to_exclude) > 0:
            for entry in nbs_to_exclude:
                if entry == notebook_name:
                    obj_list.remove(notebook_name)
    return obj_list

#print(get_notebooks_list('fc-9cd4583e-7855-4b5e-ae88-d8971cfd5b46'))
#print(get_notebooks_list('fc-9cd4583e-7855-4b5e-ae88-d8971cfd5b46', ['file_transforms.ipynb']))

def copy_notebooks(source_bucket, target_bucket, notebook_list):
    source_path = 'gs://' + source_bucket + '/notebooks'
    target_path = 'gs://' + target_bucket + '/notebooks'
    for item in notebook_list:
        # !gsutil cp $source_path/$item $target_path/ 2> stdout

def copy_resources_directory(source_bucket, target_bucket):
    source_path = 'gs://' + source_bucket + '/ingest_pipeline/resources'
    target_path = 'gs://' + target_bucket + '/ingest_pipeline'
    # !gsutil -m cp -r $source_path $target_path/

def copy_mapping_directory(source_bucket, target_bucket):
    source_path = 'gs://' + source_bucket + '/ingest_pipeline/mapping'
    target_path = 'gs://' + target_bucket + '/ingest_pipeline'
    # !gsutil -m cp -r $source_path $target_path/
    
# Run ad-hoc copy
def run_copy(src_bucket, user_project, notebooks_to_include, notebooks_to_exclude, copy_resources, copy_mapping):
    nb_copy_list = get_notebooks_list(src_bucket, user_project, notebooks_to_include, notebooks_to_exclude)
    #copy_notebooks(src_bucket, tar_bucket, nb_copy_list)
    if copy_resources:
        copy_resources_directory(src_bucket, tar_bucket)
    if copy_mapping:
        copy_mapping_directory(src_bucket, tar_bucket)

# %%
# Set parameters
user_project = "terra-92e58ed4"
src_bucket = "fc-2a9eefc3-0302-427f-9ac3-82f078741c03"
tar_bucket = "fc-701899a2-164e-4237-bd28-1cf76c5af47a"
notebooks_to_include = [] # Leave empty to copy all notebooks
notebooks_to_exclude = ["utility_copy_notebooks.ipynb", "temp_scratch.ipynb"]
copy_resources = True
copy_mapping = True

# Run copy
run_copy(src_bucket, user_project, notebooks_to_include, notebooks_to_exclude, copy_resources, copy_mapping)
# Out:
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240419163108.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240419170931.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240419172707.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240419183443.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240426180511.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240419201405.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240426191759.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240426210916.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240426195544.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/validation_results_20240420011530.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240419202812.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240419201150.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240419202939.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240422165216.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240423142434.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/azure_migration/workspace_validation_results_20240423150306.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240409204234.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240703124141.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/consent_code_lookup/dbgap_consents.csv [Content-Type=text/csv]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240410013309.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240703124624.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240703133952.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240703135524.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/dataset_stats/dataset_stats_20240703140030.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/details/file_diffs.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/details/file_diffs_20240407030803.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/details/file_diffs_20240407235037.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/details/file_diffs_20240408000222.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_0b06619d-39d9-4437-8c42-2e415faa634c.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_0e7f31a0-c712-4ebf-ab3a-64c37f43e52a.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_0701aae2-8661-4eec-84e0-7c8be1c89a18.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_0f949ee9-0986-42b2-af5d-0f4c8338c664.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_15ae6390-6f6d-4fd8-9a51-ecf988676c4d.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_18b1a7a4-1724-4e10-95ca-fa35164c4801.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_1c2fe11d-b020-4c54-8c71-1ea91623d626.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_2b08cb76-061d-44c6-a00f-b43a5421df5e.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_2c11b505-17c8-402e-8422-0239accb449d.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_2c6f63b2-439e-499f-b687-b3fdd88a492e.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_31e61d00-61cc-46f2-a793-8ea8dfbb0832.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_352a503b-41eb-4a84-b257-68d70e55337e.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_3a3100bb-369e-47c1-a77c-2cacb7cf020d.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_3eb8ea77-4605-4bb7-90f9-671953abe4a2.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_3fd2204c-8654-4af7-832f-c186447262e0.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_44161b51-953d-4f6b-9448-5cba4a44a9d8.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_470eee0f-2053-4d9b-9f5e-ca9661a6cc16.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_478aa270-fbd4-4a45-8f63-221b4066168e.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_4bc5b4eb-da91-48f7-bca0-134ed1a484a0.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_4ecbb7c8-0246-47f8-9654-4caca1d52565.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_59dafb62-a76f-4901-a778-46357f4bcd98.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_608d793e-a78b-4872-a50c-21a9eaa60ec3.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_575dc7da-58ed-407d-9e88-7b586f28bf65.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_63b229b5-e7c8-4fd3-bbc8-ecf344da70d4.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_68a916af-2e0c-41bd-8535-c7eacbc2d1b7.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_582f5f8d-b96f-490e-b417-ba824baeb06c.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_6c47e282-5d5e-445c-b6bd-c0024946fbe0.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_713f8676-8034-4827-bccc-cd6d95b1a4c4.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_732eaae3-b509-4a7a-8961-09d861e55253.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_737d39b8-2f99-4eac-bcda-a03996e08939.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_74608bd9-39e4-4f48-9b7c-1cd9d3c599c9.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_7e825ee6-7c03-43cc-b0a4-0d9203a30bd9.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_7efb1905-34b4-4f1c-a8a6-8e64b3640a68.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_7baf8e8c-de11-452d-b2e1-aad7c08cc18e.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_8d89608c-0d61-4d71-a2e3-9fbc6cda69bf.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_902596ce-714e-49b3-8271-f3dfece52309.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_93e712f2-3e54-466e-aa53-57eb69c43bc0.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_9737abab-2d09-4912-b300-f32553bda82c.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_9f7dbe05-96b5-4b2f-9f3a-34b552e3dd21.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_9cb5ce25-38e8-4628-9ddf-d6aedf5efe0f.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_a43075e3-9abd-4518-bc17-ff162d60cbde.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_a647528d-925e-4c02-8825-ff54720c6ee4.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_ab7e390a-adc5-4f9e-b317-a216a2904c93.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_b2e7f15b-65d5-4812-abfd-b2dbc6d18850.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_ae34e63e-13af-48b8-8b72-8137289091b3.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_b5c0bf91-9d20-41a2-9dd2-87d0ef0310f9.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_b5d7c34a-c383-4fc7-aa4d-b6dc941cd41a.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_b8c5b185-8669-43d1-8ec7-c0f6d223d505.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_bbba696b-d023-4bb1-a213-c8bee31e8bae.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_bcfe7f3b-3e63-45de-9e4d-144f9fc63753.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_c56f0a76-2b91-4860-8dff-63c9504bb0e2.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_c6f3bd64-ea67-488f-904f-f0bdf6320b5c.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_c8b1d323-f352-482e-bf17-82075c23dcee.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_d1e8d19a-970d-4ede-b5bc-9cab7237adec.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_d30f51c7-d642-4e7d-a168-967b9520a80a.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_d48db47e-acba-4377-b031-f6dfc21f3658.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_dea7d0d6-e27a-4447-b06f-1136c6bab6e3.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_e9c7ad29-2213-4648-9164-33a07bd42cdb.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_f1513955-0264-4733-bd25-3f752c61a323.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_eefbea02-0d65-441e-b455-35aa21d25ba3.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_f60cce71-083c-4407-8069-b76b1418aeff.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_f8d5b908-2356-4775-8792-8611776dc257.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_fa278604-7d85-4491-a30d-15c7821f8b00.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/file_inventory_diff/output/file_inventory_ff7e3be2-c0ac-4d97-85da-6229bf7585ac.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/mapping_compatibility/output/mapping_compatibility_aggregation.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/mapping_compatibility/output/mapping_compatibility_results.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/mapping_compatibility/workspace_schemas.csv [Content-Type=text/csv]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/misc/ccdg_afib_participant_metadata.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/misc/ccdg_afib_sample_metadata.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/misc/ccdg_afib_subject_metadata.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/misc/ccdg_cvd_sample_metadata.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/misc/ccdg_epi_sample_metadata.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/null_md5_files.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/search/search_facet_values.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/resources/search/search_facet_values_agg.tsv [Content-Type=text/tab-separated-values]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/cmg_ext_2/mapping_specification.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/cmg_ext_3/mapping_specification.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/gregor_1/mapping_specification.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/cmg_ext_4/mapping_specification.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/gtex_ext_2/mapping_specification.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/mapping_schema_object.json [Content-Type=application/json]...
# Copying gs://fc-2a9eefc3-0302-427f-9ac3-82f078741c03/ingest_pipeline/mapping/anvil/gtex_ext_3/mapping_specification.json [Content-Type=application/json]...
# / [7/12 files][171.6 KiB/171.6 KiB]  99% Done
